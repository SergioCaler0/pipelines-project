# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/sergio/pokemon-with-stats.csv")

# %%
df
# Out:
#       Unnamed: 0  pokedex_number  generation           species    HP  Attack  \
# 0              0               1           1      Seed Pokémon  45.0    49.0
# 1              1               2           1      Seed Pokémon  60.0    62.0
# 2              2               3           1      Seed Pokémon  80.0    82.0
# 3              3               3           1      Seed Pokémon  39.0    52.0
# 4              4               4           1    Lizard Pokémon  58.0    64.0
# ...          ...             ...         ...               ...   ...     ...
# 1023        1023             888           8   Warrior Pokémon   NaN     NaN
# 1024        1024             889           8   Warrior Pokémon   NaN     NaN
# 1025        1025             889           8   Warrior Pokémon   NaN     NaN
# 1026        1026             890           8  Gigantic Pokémon   NaN     NaN
# 1027        1027             890           8  Gigantic Pokémon   NaN     NaN
#
#       Defense  Sp-Atk  Sp-Def  Speed
# ...

# %%
data = df.drop(['Unnamed: 0', 'species'], axis = 'columns')

# %%
data
# Out:
#       pokedex_number  generation    HP  Attack  Defense  Sp-Atk  Sp-Def  Speed
# 0                  1           1  45.0    49.0     49.0    65.0    65.0   45.0
# 1                  2           1  60.0    62.0     63.0    80.0    80.0   60.0
# 2                  3           1  80.0    82.0     83.0   100.0   100.0   80.0
# 3                  3           1  39.0    52.0     43.0    60.0    50.0   65.0
# 4                  4           1  58.0    64.0     58.0    80.0    65.0   80.0
# ...              ...         ...   ...     ...      ...     ...     ...    ...
# 1023             888           8   NaN     NaN      NaN     NaN     NaN    NaN
# 1024             889           8   NaN     NaN      NaN     NaN     NaN    NaN
# 1025             889           8   NaN     NaN      NaN     NaN     NaN    NaN
# 1026             890           8   NaN     NaN      NaN     NaN     NaN    NaN
# 1027             890           8   NaN     NaN      NaN     NaN     NaN    NaN
#
# [1028 rows x 8 columns]

# %%
df1 = pd.read_csv("/home/sergio/set_scraping_tratado.csv")

# %%
df1
# Out:
#       Unnamed: 0        name          types  stats
# 0              0   Bulbasaur   Grass Poison    318
# 1              1     Ivysaur   Grass Poison    405
# 2              2    Venusaur   Grass Poison    525
# 3              3    Venusaur   Grass Poison    625
# 4              4  Charmander          Fire     309
# ...          ...         ...            ...    ...
# 1040        1040   Glastrier           Ice     580
# 1041        1041   Spectrier         Ghost     580
# 1042        1042     Calyrex  Psychic Grass    500
# 1043        1043     Calyrex    Psychic Ice    680
# 1044        1044     Calyrex  Psychic Ghost    680
#
# [1045 rows x 4 columns]

# %%
data = df1.drop(['Unnamed: 0'], axis = 'columns')

# %%
data_final=pd.concat([df,data], axis=1)

# %%
data_final
# Out:
#       Unnamed: 0  pokedex_number  generation         species    HP  Attack  \
# 0            0.0             1.0         1.0    Seed Pokémon  45.0    49.0
# 1            1.0             2.0         1.0    Seed Pokémon  60.0    62.0
# 2            2.0             3.0         1.0    Seed Pokémon  80.0    82.0
# 3            3.0             3.0         1.0    Seed Pokémon  39.0    52.0
# 4            4.0             4.0         1.0  Lizard Pokémon  58.0    64.0
# ...          ...             ...         ...             ...   ...     ...
# 1040         NaN             NaN         NaN             NaN   NaN     NaN
# 1041         NaN             NaN         NaN             NaN   NaN     NaN
# 1042         NaN             NaN         NaN             NaN   NaN     NaN
# 1043         NaN             NaN         NaN             NaN   NaN     NaN
# 1044         NaN             NaN         NaN             NaN   NaN     NaN
#
# ...

# %%
dataF = data_final.drop(['Unnamed: 0', 'species'], axis = 'columns')

# %%
dataF
# Out:
#       pokedex_number  generation    HP  Attack  Defense  Sp-Atk  Sp-Def  \
# 0                1.0         1.0  45.0    49.0     49.0    65.0    65.0
# 1                2.0         1.0  60.0    62.0     63.0    80.0    80.0
# 2                3.0         1.0  80.0    82.0     83.0   100.0   100.0
# 3                3.0         1.0  39.0    52.0     43.0    60.0    50.0
# 4                4.0         1.0  58.0    64.0     58.0    80.0    65.0
# ...              ...         ...   ...     ...      ...     ...     ...
# 1040             NaN         NaN   NaN     NaN      NaN     NaN     NaN
# 1041             NaN         NaN   NaN     NaN      NaN     NaN     NaN
# 1042             NaN         NaN   NaN     NaN      NaN     NaN     NaN
# 1043             NaN         NaN   NaN     NaN      NaN     NaN     NaN
# 1044             NaN         NaN   NaN     NaN      NaN     NaN     NaN
#
#       Speed        name          types  stats
# 0      45.0   Bulbasaur   Grass Poison    318
# ...

# %%
primerag=dataF[dataF.generation == 1]

# %%
primerag
# Out:
#      pokedex_number  generation    HP  Attack  Defense  Sp-Atk  Sp-Def  Speed  \
# 0               1.0         1.0  45.0    49.0     49.0    65.0    65.0   45.0
# 1               2.0         1.0  60.0    62.0     63.0    80.0    80.0   60.0
# 2               3.0         1.0  80.0    82.0     83.0   100.0   100.0   80.0
# 3               3.0         1.0  39.0    52.0     43.0    60.0    50.0   65.0
# 4               4.0         1.0  58.0    64.0     58.0    80.0    65.0   80.0
# ..              ...         ...   ...     ...      ...     ...     ...    ...
# 187           149.0         1.0   NaN     NaN      NaN     NaN     NaN    NaN
# 188           150.0         1.0   NaN     NaN      NaN     NaN     NaN    NaN
# 189           150.0         1.0   NaN     NaN      NaN     NaN     NaN    NaN
# 190           150.0         1.0   NaN     NaN      NaN     NaN     NaN    NaN
# 191           151.0         1.0   NaN     NaN      NaN     NaN     NaN    NaN
#
# ...

# %%
primerag.stats.mean()
# Out:
# 419.4427083333333

# %%
primerag.stats.max()
# Out:
# 640

# %%
primerag.head(5)
# Out:
#    pokedex_number  generation    HP  Attack  Defense  Sp-Atk  Sp-Def  Speed  \
# 0             1.0         1.0  45.0    49.0     49.0    65.0    65.0   45.0
# 1             2.0         1.0  60.0    62.0     63.0    80.0    80.0   60.0
# 2             3.0         1.0  80.0    82.0     83.0   100.0   100.0   80.0
# 3             3.0         1.0  39.0    52.0     43.0    60.0    50.0   65.0
# 4             4.0         1.0  58.0    64.0     58.0    80.0    65.0   80.0
#
#          name         types  stats
# 0   Bulbasaur  Grass Poison    318
# 1     Ivysaur  Grass Poison    405
# 2    Venusaur  Grass Poison    525
# 3    Venusaur  Grass Poison    625
# 4  Charmander         Fire     309

# %%
#sns.countplot(primerag["types"])
#plt.hist(primerag.types)
sns.countplot(y="types", data=primerag, palette="icefire",
              order=primerag["types"].value_counts().iloc[:20].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='types'>
